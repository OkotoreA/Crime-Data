# %%
import numpy as np
import pandas as pd

# %%
Crime=pd.read_csv(r"C:\Users\Abraham okotore\Downloads\CrimeData.csv", engine ="python")

# %%
Crime
# Out:
#       Unnamed: 0            Victim's name Victim_age Victim_gender  \
# 0              1               Tyree Bell         31          Male
# 1              2             Abel Gurrola         26          Male
# 2              3      Christopher Tavares         21          Male
# 3              4              Mark Chavez         49          Male
# 4              5        Andrew L. Closson         21          Male
# ...          ...                      ...        ...           ...
# 7676        7677  Name withheld by police        NaN          Male
# 7677        7678        Frederick Perkins         37          Male
# 7678        7679           Malik Williams         23          Male
# 7679        7680             Brian Elkins         47          Male
# 7680        7681    Michael Vincent Davis         49          Male
#
#        Victim_race                             URL of image of victim  \
# 0            Black  http://content.omaha.com/media/maps/ps/2013/ja...
# ...

# %%
Crime["Unarmed"].value_counts()
# Out:
# Allegedly Armed    5675
# Unarmed            1019
# Unclear             530
# Vehicle             457
# Name: Unarmed, dtype: int64

# %%
Crime.dtypes
# Out:
# Unnamed: 0                                                                                                                                                                      int64
# Victim's name                                                                                                                                                                  object
# Victim_age                                                                                                                                                                     object
# Victim_gender                                                                                                                                                                  object
# Victim_race                                                                                                                                                                    object
# ...

# %%
Crime['date'] = pd.to_datetime(Crime.date)
Crime.groupby(Crime.date.dt.year).transform('mean')
# Out:
#       Unnamed: 0                          date       Zipcode  \
# 0            556 2013-06-28 23:31:29.108913664  58718.748639
# 1            556 2013-06-28 23:31:29.108913664  58718.748639
# 2            556 2013-06-28 23:31:29.108913664  58718.748639
# 3            556 2013-06-28 23:31:29.108913664  58718.748639
# 4            556 2013-06-28 23:31:29.108913664  58718.748639
# ...          ...                           ...           ...
# 7676        7132 2019-07-03 03:04:44.986353664  60680.985401
# 7677        7132 2019-07-03 03:04:44.986353664  60680.985401
# 7678        7132 2019-07-03 03:04:44.986353664  60680.985401
# 7679        7132 2019-07-03 03:04:44.986353664  60680.985401
# 7680        7132 2019-07-03 03:04:44.986353664  60680.985401
#
#       Body Camera (Source: WaPo)  WaPo ID (If included in WaPo database)
# 0                            NaN                                     NaN
# 1                            NaN                                     NaN
# ...

# %%
Crime.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0            Victim's name Victim_age Victim_gender  \
# 0              1               Tyree Bell         31          Male
# 1              2             Abel Gurrola         26          Male
# 2              3      Christopher Tavares         21          Male
# 3              4              Mark Chavez         49          Male
# 4              5        Andrew L. Closson         21          Male
# ...          ...                      ...        ...           ...
# 7676        7677  Name withheld by police        NaN          Male
# 7677        7678        Frederick Perkins         37          Male
# 7678        7679           Malik Williams         23          Male
# 7679        7680             Brian Elkins         47          Male
# 7680        7681    Michael Vincent Davis         49          Male
#
#        Victim_race                             URL of image of victim  \
# ...

# %%
result=Crime["Victim_race"].value_counts()

# %%
result
# Out:
# White               3385
# Black               1949
# Hispanic            1339
# Unknown race         672
# Asian                118
# Native American      112
# Unknown Race          64
# Pacific Islander      42
# Name: Victim_race, dtype: int64

# %%
result=Crime["Victim_race"].value_counts()

# %%
result
# Out:
# White               3385
# Black               1949
# Hispanic            1339
# Unknown race         672
# Asian                118
# Native American      112
# Unknown Race          64
# Pacific Islander      42
# Name: Victim_race, dtype: int64

# %%
result.plot(kind="pie", autopct="%1.1f%%")
plt.legend()

# %%
import matplotlib as pyplot

# %%
import matplotlib.pyplot as  plt

# %%
Crime["Victim_gender"].value_counts()
# Out:
# Male           7271
# Female          391
# Transgender       7
# Unknown           4
# Name: Victim_gender, dtype: int64

# %%
new=Crime["Victim_gender"].value_counts()

# %%
new
# Out:
# Male           7271
# Female          391
# Transgender       7
# Unknown           4
# Name: Victim_gender, dtype: int64

# %%
new.plot(kind="pie", autopct="%1.1f%%", explode=(0.1, 0.1,0.1,0))
plt.legend()

# %%
x=Crime["State"].value_counts()

# %%
x
# Out:
# CA    1189
# TX     721
# FL     540
# AZ     343
# GA     266
# CO     227
# WA     219
# OK     215
# OH     215
# NC     204
# MO     197
# IL     181
# TN     179
# PA     171
# NY     156
# LA     148
# NM     143
# AL     138
# MD     128
# IN     126
# MI     124
# VA     124
# KY     122
# NV     122
# SC     121
# OR     113
# WI     111
# MS     109
# AR     103
# NJ     103
# MN      84
# UT      82
# KS      75
# WV      74
# MA      56
# ID      48
# IA      46
# AK      41
# MT      40
# HI      37
# CT      36
# NE      36
# ME      31
# DC      27
# SD      25
# DE      20
# WY      19
# NH      17
# VT      12
# ND      11
# RI       6
# Name: State, dtype: int64

# %%
plt.hist(x, density=False)
plt.xlabel()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-3847065b7f47> in <module>
#       1 plt.hist(x, density=False)
# ----> 2 plt.xlabel()
#
# TypeError: xlabel() missing 1 required positional argument: 'xlabel'
